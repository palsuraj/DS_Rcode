# %% [markdown]
# <a href="https://colab.research.google.com/github/YG-0/DS_Rcodes/blob/main/1_Neural_Network_Back_Propagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install tensorflow

# %%
#!pip install keras

# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("/content/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8,  activation='relu'))
model.add(Dense(8,  activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=250, batch_size=20)
# Out:
# Epoch 1/250
# 26/26 [==============================] - 1s 9ms/step - loss: 8.8642 - accuracy: 0.4883 - val_loss: 4.6528 - val_accuracy: 0.4646
# Epoch 2/250
# 26/26 [==============================] - 0s 3ms/step - loss: 3.1137 - accuracy: 0.4241 - val_loss: 1.2838 - val_accuracy: 0.4094
# Epoch 3/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.9022 - accuracy: 0.5447 - val_loss: 0.9248 - val_accuracy: 0.5315
# Epoch 4/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.7880 - accuracy: 0.6051 - val_loss: 0.8740 - val_accuracy: 0.5551
# Epoch 5/250
# 26/26 [==============================] - 0s 5ms/step - loss: 0.7579 - accuracy: 0.6498 - val_loss: 0.8502 - val_accuracy: 0.5630
# Epoch 6/250
# 26/26 [==============================] - 0s 3ms/step - loss: 0.7162 - accuracy: 0.6595 - val_loss: 0.8216 - val_accuracy: 0.5591
# Epoch 7/250
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5279 - accuracy: 0.7253
# accuracy: 72.53%
